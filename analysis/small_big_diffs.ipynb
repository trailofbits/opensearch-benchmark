# %%
# !pip install pandas seaborn scipy
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: seaborn in ./venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: scipy in ./venv/lib/python3.13/site-packages (1.14.1)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.13/site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./venv/lib/python3.13/site-packages (from seaborn) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import glob
from scipy import stats
import numpy as np

pd.options.mode.copy_on_write = True

# %%
categories_df = pd.read_csv("~/Downloads/2024-12-18 _ Benchmark Results - Categories.csv")
d = categories_df.to_dict()

extract_values = lambda l: [y[1] for y in sorted(d[l].items(), key=lambda x: x[0])]
category_map = {(workload, op): category for workload, op, category in zip(extract_values('Workload'), extract_values('Operation'), extract_values('Category'))}

# %%
df = pd.read_csv("~/Downloads/2024-12-10 _ Benchmark Results - raw.csv")
df = df[df['name'] == 'service_time']

df['category'] = df.apply(lambda row: category_map.get((row['workload'], row['operation']), None), axis=1)
df = df[~(df["distribution-version"].isin(["8.8.1", "8.11.4"]))]
print(df['distribution-version'].unique())
df.head()
# Out:
# ['2.18.0' '2.17.1' '8.15.4' '2.16.0']
#    user-tags\.run-group            environment user-tags\.engine-type  \
# 60   2024-12-02 2:37:20  gh-nightly-1733107040                     OS
# 61   2024-12-02 2:37:20  gh-nightly-1733107040                     OS
# 62   2024-12-02 2:37:20  gh-nightly-1733107040                     OS
# 63   2024-12-02 2:37:20  gh-nightly-1733107040                     OS
# 64   2024-12-02 2:37:20  gh-nightly-1733107040                     OS
#
#    distribution-version              workload workload_subtype  \
# 60               2.18.0  noaa_semantic_search              NaN
# 61               2.18.0  noaa_semantic_search              NaN
# 62               2.18.0  noaa_semantic_search              NaN
# 63               2.18.0  noaa_semantic_search              NaN
# 64               2.18.0  noaa_semantic_search              NaN
#
#                 test-procedure  user-tags\.run  \
# 60  hybrid-query-aggs-no-index               0
# 61  hybrid-query-aggs-no-index               0
# 62  hybrid-query-aggs-no-index               0
# 63  hybrid-query-aggs-no-index               0
# 64  hybrid-query-aggs-no-index               0
#
#                                             operation          name  ...  \
# 60                      aggs-query-min-avg-sum-hybrid  service_time  ...
# 61  aggs-query-range-numeric-significant-terms-hybrid  service_time  ...
# 62  aggs-query-date-histo-geohash-grid-hybrid-one-...  service_time  ...
# 63  aggs-query-min-avg-sum-hybrid-one-subquery-med...  service_time  ...
# 64  aggs-query-term-min-hybrid-one-subquery-medium...  service_time  ...
#
#     value\.90_0  workload\.target_throughput  workload\.number_of_replicas  \
# 60     2.164169                          NaN                           0.0
# 61     1.829712                          NaN                           0.0
# 62     1.465304                          NaN                           0.0
# 63     1.427159                          NaN                           0.0
# 64     1.432932                          NaN                           0.0
#
#     workload\.bulk_indexing_clients  workload\.max_num_segments  \
# 60                              NaN                         8.0
# 61                              NaN                         8.0
# 62                              NaN                         8.0
# 63                              NaN                         8.0
# 64                              NaN                         8.0
#
#     user-tags\.shard-count  user-tags\.replica-count  \
# 60                       6                         0
# 61                       6                         0
# 62                       6                         0
# 63                       6                         0
# 64                       6                         0
#
#     workload\.query_data_set_corpus workload\.target_index_body     category
# 60                              NaN                         NaN  Aggregation
# 61                              NaN                         NaN  Aggregation
# 62                              NaN                         NaN  Aggregation
# 63                              NaN                         NaN  Aggregation
# 64                              NaN                         NaN  Aggregation
#
# [5 rows x 21 columns]

# %%
results = []
df_engine = df[df["distribution-version"].isin(["8.15.4", "2.18.0"])]
for workload in ["pmc", "nyc_taxis", "noaa", "big5", "noaa_semantic_search"]:
    # df_engine = df[df["user-tags\\.engine-type"] == "OS"]
    df_workload = df_engine[df_engine['workload'] == workload]
    
    for (engine_type, engine_version, operation, category), group in df_workload.groupby(["user-tags\\.engine-type", "distribution-version", "operation", "category"]):
        values = group["value\\.90_0"]
        results.append({
            "workload": workload,
            "engine_type": engine_type,
            "engine_version": engine_version,
            "operation": operation,
            "category": category,
            "p90th": values.mean(),
        })
        # print(engine_type, engine_version, workload, operation, values.mean(), values.median())

results_df = pd.DataFrame(results)
results_df
# Out:
#                  workload engine_type engine_version  \
# 0                     pmc          ES         8.15.4
# 1                     pmc          ES         8.15.4
# 2                     pmc          ES         8.15.4
# 3                     pmc          ES         8.15.4
# 4                     pmc          ES         8.15.4
# ..                    ...         ...            ...
# 171  noaa_semantic_search          OS         2.18.0
# 172  noaa_semantic_search          OS         2.18.0
# 173  noaa_semantic_search          OS         2.18.0
# 174  noaa_semantic_search          OS         2.18.0
# 175  noaa_semantic_search          OS         2.18.0
#
#                                              operation            category  \
# 0                          articles_monthly_agg_cached         Aggregation
# 1                        articles_monthly_agg_uncached         Aggregation
# 2                                              default  General Operations
# 3                                               phrase       Text Querying
# 4                                               scroll  General Operations
# ..                                                 ...                 ...
# 171  aggs-query-term-min-hybrid-one-subquery-medium...         Aggregation
# 172                            hybrid-query-only-range        Hybrid Query
# 173               hybrid-query-only-range-large-subset        Hybrid Query
# 174              hybrid-query-only-range-medium-subset        Hybrid Query
# 175                  hybrid-query-only-term-range-date        Hybrid Query
#
#           p90th
# 0      1.218702
# 1      6.788204
# 2      3.103733
# 3      3.634737
# 4    257.126625
# ..          ...
# 171    1.462272
# 172    1.495748
# 173    1.466839
# 174    1.480840
# 175    1.777204
#
# [176 rows x 6 columns]

# %%
close_results = []
big_results = []
threshold = 0.05
for (workload, operation, category), group in results_df.groupby(["workload", "operation", "category"]):
    es_group = group[group["engine_type"] == "ES"]
    os_group = group[group["engine_type"] == "OS"]

    if es_group.empty or os_group.empty:
        continue

    es_val = es_group["p90th"].iloc[0]
    os_val = os_group["p90th"].iloc[0]

    if es_val > os_val:
        pct_diff = (es_val) / os_val * 100 - 100
    elif os_val > es_val:
        pct_diff = (os_val) / es_val * 100 - 100
        
    if pct_diff < 5:
        close_results.append((
            category,
            workload,
            "ES" if es_val > os_val else "OS",
            operation,
            es_val,
            os_val,
            pct_diff
        ))
    else:
        big_results.append((
            category,
            workload,
            "ES" if es_val > os_val else "OS",
            operation,
            es_val,
            os_val,
            pct_diff
        ))

print()
print()
print("====================")
print(f"# < 5% difference ({len(close_results)})")
for category, workload, engine_type, operation, es_val, os_val, pct_diff in sorted(close_results, key=lambda x: (x[0], x[-1])):
    print(f"{category:<25} | {workload + " / " + operation:<60} | ES {es_val:>7.2f}ms | OS {os_val:>7.2f}ms | {engine_type} slower by {pct_diff:.0f}%")


print()
print()
print("====================")
print(f"# > 5% difference ({len(big_results)})")
for category, workload, engine_type, operation, es_val, os_val, pct_diff in sorted(big_results, key=lambda x: (x[0], x[-1])):
    print(f"{category:<25} | {workload + " / " + operation:<60} | ES {es_val:>7.2f}ms | OS {os_val:>7.2f}ms | {engine_type} slower by {pct_diff:.0f}%")

print()
print()
print("====================")
huge_results = [x for x in big_results if x[-1] > 500]
print(f"# Huge differences ({len(huge_results)})")
for category, workload, engine_type, operation, es_val, os_val, pct_diff in sorted(huge_results, key=lambda x: (x[-1])):
    print(f"{category:<25} | {workload + " / " + operation:<60} | ES {es_val:>7.2f}ms | OS {os_val:>7.2f}ms | {engine_type} {pct_diff/100:.0f}x slower")
# Out:
# ====================
# # < 5% difference (16)
# Date Histogram            | noaa / date-histo-string-significant-terms-via-default-strategy | ES 2665.47ms | OS 2726.23ms | OS slower by 2%
# Date Histogram            | noaa / date-histo-numeric-terms                              | ES 2102.18ms | OS 2150.12ms | OS slower by 2%
# Date Histogram            | noaa / date-histo-string-significant-terms-via-global-ords   | ES 2661.66ms | OS 2724.63ms | OS slower by 2%
# Date Histogram            | noaa / date-histo-string-terms-via-global-ords               | ES 2363.10ms | OS 2442.72ms | OS slower by 3%
# Date Histogram            | noaa / date-histo-string-terms-via-default-strategy          | ES 2358.76ms | OS 2438.84ms | OS slower by 3%
# Date Histogram            | noaa / date-histo-entire-range                               | ES    2.29ms | OS    2.21ms | ES slower by 4%
# Range Queries             | big5 / range_field_conjunction_big_range_big_term_query      | ES    0.84ms | OS    0.84ms | ES slower by 0%
# Range Queries             | big5 / range_field_conjunction_small_range_small_term_query  | ES    0.82ms | OS    0.82ms | OS slower by 1%
# Range Queries             | big5 / range_field_disjunction_big_range_small_term_query    | ES    0.83ms | OS    0.84ms | OS slower by 2%
# Range Queries             | big5 / range_field_conjunction_small_range_big_term_query    | ES    0.72ms | OS    0.76ms | OS slower by 5%
# Sorting                   | big5 / sort_keyword_no_can_match_shortcut                    | ES    2.24ms | OS    2.16ms | ES slower by 4%
# Sorting                   | big5 / sort_keyword_can_match_shortcut                       | ES    2.27ms | OS    2.17ms | ES slower by 5%
# Term Aggregations         | big5 / composite-terms                                       | ES  224.56ms | OS  226.01ms | OS slower by 1%
# Term Aggregations         | noaa / keyword-terms-min                                     | ES 2093.71ms | OS 2020.40ms | ES slower by 4%
# Text Querying             | big5 / term                                                  | ES    0.92ms | OS    0.91ms | ES slower by 1%
# Text Querying             | big5 / query-string-on-message-filtered-sorted-num           | ES   25.20ms | OS   25.88ms | OS slower by 3%
#
#
# ====================
# # > 5% difference (62)
# Aggregation               | nyc_taxis / date_histogram_agg                               | ES    4.29ms | OS    4.05ms | ES slower by 6%
# Aggregation               | pmc / articles_monthly_agg_uncached                          | ES    6.79ms | OS    6.36ms | ES slower by 7%
# Aggregation               | pmc / articles_monthly_agg_cached                            | ES    1.22ms | OS    1.61ms | OS slower by 32%
# Aggregation               | nyc_taxis / distance_amount_agg                              | ES 2815.21ms | OS 11368.65ms | OS slower by 304%
# Aggregation               | nyc_taxis / autohisto_agg                                    | ES  273.66ms | OS    4.22ms | ES slower by 6384%
# Date Histogram            | noaa / date-histo-string-significant-terms-via-map           | ES 10517.90ms | OS 11463.00ms | OS slower by 9%
# Date Histogram            | noaa / date-histo-string-terms-via-map                       | ES 10198.17ms | OS 11141.69ms | OS slower by 9%
# Date Histogram            | big5 / range-auto-date-histo                                 | ES 2584.54ms | OS 9339.66ms | OS slower by 261%
# Date Histogram            | big5 / range-auto-date-histo-with-metrics                    | ES 5331.18ms | OS 20559.88ms | OS slower by 286%
# Date Histogram            | noaa / date-histo-histo                                      | ES  399.86ms | OS 1669.79ms | OS slower by 318%
# Date Histogram            | noaa / date-histo-geohash-grid                               | ES  328.16ms | OS 1395.06ms | OS slower by 325%
# Date Histogram            | noaa / date-histo-geotile-grid                               | ES  364.41ms | OS 1847.02ms | OS slower by 407%
# Date Histogram            | big5 / date_histogram_minute_agg                             | ES 1245.84ms | OS   33.65ms | ES slower by 3603%
# Date Histogram            | big5 / date_histogram_hourly_agg                             | ES 1372.68ms | OS    4.97ms | ES slower by 27505%
# Date Histogram            | big5 / composite-date_histogram-daily                        | ES 1672.96ms | OS    1.23ms | ES slower by 136452%
# General Operations        | pmc / default                                                | ES    3.10ms | OS    3.74ms | OS slower by 20%
# General Operations        | big5 / scroll                                                | ES  215.41ms | OS  296.03ms | OS slower by 37%
# General Operations        | big5 / default                                               | ES    1.78ms | OS    2.64ms | OS slower by 48%
# General Operations        | nyc_taxis / default                                          | ES    1.82ms | OS    3.04ms | OS slower by 67%
# General Operations        | pmc / scroll                                                 | ES  257.13ms | OS  622.16ms | OS slower by 142%
# Range & Date Histogram    | noaa / range-auto-date-histo-with-metrics                    | ES  595.33ms | OS 3423.89ms | OS slower by 475%
# Range & Date Histogram    | noaa / range-date-histo-with-metrics                         | ES  444.35ms | OS 2649.45ms | OS slower by 496%
# Range & Date Histogram    | noaa / range-auto-date-histo                                 | ES  208.78ms | OS 1865.17ms | OS slower by 793%
# Range & Date Histogram    | noaa / range-auto-date-histo-with-time-zone                  | ES  210.98ms | OS 1891.12ms | OS slower by 796%
# Range & Date Histogram    | noaa / range-date-histo                                      | ES  168.26ms | OS 1579.94ms | OS slower by 839%
# Range Queries             | big5 / range-numeric                                         | ES    0.75ms | OS    0.79ms | OS slower by 6%
# Range Queries             | big5 / range-agg-2                                           | ES    1.17ms | OS    1.01ms | ES slower by 15%
# Range Queries             | big5 / range                                                 | ES    8.86ms | OS    7.45ms | ES slower by 19%
# Range Queries             | noaa / range-aggregation                                     | ES    3.10ms | OS    4.05ms | OS slower by 31%
# Range Queries             | big5 / range-agg-1                                           | ES    1.34ms | OS    1.01ms | ES slower by 32%
# Range Queries             | noaa / range-numeric-significant-terms                       | ES 1221.20ms | OS 2353.93ms | OS slower by 93%
# Range Queries             | nyc_taxis / range                                            | ES   63.38ms | OS  189.81ms | OS slower by 200%
# Range Queries             | big5 / keyword-in-range                                      | ES   12.95ms | OS   61.77ms | OS slower by 377%
# Sorting                   | big5 / sort_numeric_asc_with_match                           | ES    0.75ms | OS    0.81ms | OS slower by 7%
# Sorting                   | big5 / sort_numeric_desc_with_match                          | ES    0.74ms | OS    0.80ms | OS slower by 8%
# Sorting                   | big5 / sort_numeric_desc                                     | ES    3.62ms | OS    4.40ms | OS slower by 22%
# Sorting                   | big5 / sort_numeric_asc                                      | ES    3.01ms | OS    3.77ms | OS slower by 25%
# Sorting                   | big5 / asc_sort_with_after_timestamp                         | ES  385.09ms | OS  178.25ms | ES slower by 116%
# Sorting                   | big5 / desc_sort_with_after_timestamp                        | ES   81.68ms | OS  249.67ms | OS slower by 206%
# Sorting                   | big5 / asc_sort_timestamp_no_can_match_shortcut              | ES   17.88ms | OS    5.36ms | ES slower by 234%
# Sorting                   | big5 / asc_sort_timestamp_can_match_shortcut                 | ES   17.91ms | OS    5.30ms | ES slower by 238%
# Sorting                   | big5 / desc_sort_timestamp_can_match_shortcut                | ES    2.98ms | OS   11.74ms | OS slower by 294%
# Sorting                   | big5 / desc_sort_timestamp_no_can_match_shortcut             | ES    2.94ms | OS   11.72ms | OS slower by 299%
# Sorting                   | big5 / asc_sort_timestamp                                    | ES   21.85ms | OS    5.31ms | ES slower by 312%
# Sorting                   | big5 / desc_sort_timestamp                                   | ES    3.66ms | OS   50.14ms | OS slower by 1270%
# Sorting                   | nyc_taxis / desc_sort_tip_amount                             | ES 6058.43ms | OS    4.10ms | ES slower by 147743%
# Sorting                   | nyc_taxis / asc_sort_tip_amount                              | ES 6127.93ms | OS    3.29ms | ES slower by 186121%
# Term Aggregations         | big5 / composite_terms-keyword                               | ES  326.20ms | OS  343.17ms | OS slower by 5%
# Term Aggregations         | noaa / numeric-terms-numeric-terms                           | ES 1737.18ms | OS 1845.67ms | OS slower by 6%
# Term Aggregations         | noaa / keyword-terms-numeric-terms                           | ES 5638.99ms | OS 5265.07ms | ES slower by 7%
# Term Aggregations         | big5 / cardinality-agg-low                                   | ES    1.04ms | OS    1.84ms | OS slower by 76%
# Term Aggregations         | big5 / multi_terms-keyword                                   | ES 1338.62ms | OS  756.41ms | ES slower by 77%
# Term Aggregations         | big5 / cardinality-agg-high                                  | ES  758.52ms | OS 2334.36ms | OS slower by 208%
# Term Aggregations         | noaa / keyword-terms-low-cardinality                         | ES   12.52ms | OS    3.86ms | ES slower by 225%
# Term Aggregations         | noaa / keyword-terms                                         | ES 1031.26ms | OS  153.99ms | ES slower by 570%
# Term Aggregations         | noaa / keyword-terms-low-cardinality-min                     | ES  198.33ms | OS 1499.22ms | OS slower by 656%
# Term Aggregations         | big5 / keyword-terms                                         | ES 3019.08ms | OS   34.36ms | ES slower by 8687%
# Term Aggregations         | big5 / keyword-terms-low-cardinality                         | ES 2994.50ms | OS   21.04ms | ES slower by 14130%
# Text Querying             | pmc / phrase                                                 | ES    3.63ms | OS    4.00ms | OS slower by 10%
# Text Querying             | pmc / term                                                   | ES    3.28ms | OS    4.39ms | OS slower by 34%
# Text Querying             | big5 / query-string-on-message-filtered                      | ES   10.97ms | OS   27.23ms | OS slower by 148%
# Text Querying             | big5 / query-string-on-message                               | ES   13.03ms | OS  146.63ms | OS slower by 1025%
#
#
# ====================
# # Huge differences (15)
# Term Aggregations         | noaa / keyword-terms                                         | ES 1031.26ms | OS  153.99ms | ES 6x slower
# Term Aggregations         | noaa / keyword-terms-low-cardinality-min                     | ES  198.33ms | OS 1499.22ms | OS 7x slower
# Range & Date Histogram    | noaa / range-auto-date-histo                                 | ES  208.78ms | OS 1865.17ms | OS 8x slower
# Range & Date Histogram    | noaa / range-auto-date-histo-with-time-zone                  | ES  210.98ms | OS 1891.12ms | OS 8x slower
# Range & Date Histogram    | noaa / range-date-histo                                      | ES  168.26ms | OS 1579.94ms | OS 8x slower
# Text Querying             | big5 / query-string-on-message                               | ES   13.03ms | OS  146.63ms | OS 10x slower
# Sorting                   | big5 / desc_sort_timestamp                                   | ES    3.66ms | OS   50.14ms | OS 13x slower
# Date Histogram            | big5 / date_histogram_minute_agg                             | ES 1245.84ms | OS   33.65ms | ES 36x slower
# Aggregation               | nyc_taxis / autohisto_agg                                    | ES  273.66ms | OS    4.22ms | ES 64x slower
# Term Aggregations         | big5 / keyword-terms                                         | ES 3019.08ms | OS   34.36ms | ES 87x slower
# Term Aggregations         | big5 / keyword-terms-low-cardinality                         | ES 2994.50ms | OS   21.04ms | ES 141x slower
# Date Histogram            | big5 / date_histogram_hourly_agg                             | ES 1372.68ms | OS    4.97ms | ES 275x slower
# Date Histogram            | big5 / composite-date_histogram-daily                        | ES 1672.96ms | OS    1.23ms | ES 1365x slower
# Sorting                   | nyc_taxis / desc_sort_tip_amount                             | ES 6058.43ms | OS    4.10ms | ES 1477x slower
# Sorting                   | nyc_taxis / asc_sort_tip_amount                              | ES 6127.93ms | OS    3.29ms | ES 1861x slower
